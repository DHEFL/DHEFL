# %%
import pandas as pd

import config_FL
M = config_FL.num_client()

path = "MNIST/"+str(M)+"clients/client"
for i in range(M):
    partition_name=path+str(i)+".csv"
    dataset = pd.read_csv(partition_name)
    print(partition_name)
    print(dataset["label"].unique())
# Out:
# MNIST/200clients/client0.csv
# [0. 4. 6. 8.]
# MNIST/200clients/client1.csv
# [1. 4. 6. 7.]
# MNIST/200clients/client2.csv
# [2. 5. 7. 9.]
# MNIST/200clients/client3.csv
# [2. 3. 4. 8.]
# MNIST/200clients/client4.csv
# [1. 2. 4. 9.]
# MNIST/200clients/client5.csv
# [4. 5. 8. 9.]
# MNIST/200clients/client6.csv
# [1. 2. 4. 6.]
# MNIST/200clients/client7.csv
# [1. 5. 7. 8.]
# MNIST/200clients/client8.csv
# [1. 5. 6. 8.]
# MNIST/200clients/client9.csv
# [3. 5. 8. 9.]
# MNIST/200clients/client10.csv
# [0. 4. 7. 8.]
# MNIST/200clients/client11.csv
# [0. 1. 6. 8.]
# MNIST/200clients/client12.csv
# [0. 2. 7. 9.]
# MNIST/200clients/client13.csv
# [1. 3. 5. 9.]
# MNIST/200clients/client14.csv
# [2. 3. 4. 8.]
# MNIST/200clients/client15.csv
# [1. 5. 7. 8.]
# MNIST/200clients/client16.csv
# [1. 4. 6. 7.]
# MNIST/200clients/client17.csv
# [1. 4. 7. 8.]
# MNIST/200clients/client18.csv
# [3. 5. 8. 9.]
# MNIST/200clients/client19.csv
# [4. 7. 8. 9.]
# MNIST/200clients/client20.csv
# [0. 1. 6. 9.]
# ...
